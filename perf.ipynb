# %%
import pandas as pd
import pymysql
conn = pymysql.connect(
    host = '192.168.194.213',
    user = 'root',
    password = '123456',
    database = 'jenkins',
    port = 33060
)

mysql_page = pd.read_sql("select build_displayname,buildTime,buildid,webgl,glmark2,glxgears,heaven_1080P_low,BoardType,OS,Test_Host_IP from perf_test where  buildTime > '2024-01-01' and BoardType in ('G2D30') and OS = 'ubuntu' order by BoardType,buildTime",con=conn)
mysql_all = pd.read_sql("select * from perf_test",con=conn)
# Out:
# C:\Users\quan.yu-ext\AppData\Local\Temp\ipykernel_9780\3159507532.py:11: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   mysql_page = pd.read_sql("select build_displayname,buildTime,buildid,webgl,glmark2,glxgears,heaven_1080P_low,BoardType,OS,Test_Host_IP from perf_test where  buildTime > '2024-01-01' and BoardType in ('G2D30') and OS = 'ubuntu' order by BoardType,buildTime",con=conn)
# C:\Users\quan.yu-ext\AppData\Local\Temp\ipykernel_9780\3159507532.py:12: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   mysql_all = pd.read_sql("select * from perf_test",con=conn)

# %%
mysql_page
# Out:
#    build_displayname           buildTime buildid webgl  glmark2 glxgears  \
# 0         2024-01-01 2024-01-01 17:00:12    2615    55     9995  12610.1
# 1         2024-01-02 2024-01-02 17:00:10    2621    55  10169.3  13523.8
# 2         2024-01-03 2024-01-04 09:56:35    2635    55  10536.7    14737
# 3         2024-01-04 2024-01-05 09:56:56    2649    56    10506  14591.8
# 4         2024-01-05 2024-01-05 17:00:14    2654    54  10509.7  14596.8
# 5         2024-01-10 2024-01-10 17:00:12    2673    52    10551  14690.7
# 6         2024-01-11 2024-01-11 17:00:13    2677    53  10523.3  14715.3
# 7         2024-01-12 2024-01-12 17:00:12    2682    52  10548.3  14560.6
# 8         2024-01-15 2024-01-15 17:00:12    2687    54  10527.7  14677.4
# 9         2024-01-16 2024-01-16 20:02:43    2692    55  10532.7  14738.5
# 10        2024-01-17 2024-01-17 17:00:15    2698    56    10554  14656.8
# 11        2024-01-18 2024-01-18 17:00:16    2702    55    10523  14507.4
# ...

# %%
mysql_page.to_csv("1.csv")

# %%
mysql_all.to_csv("2.csv")

# %%
mysql_page.shape
# Out:
# (27, 7)

# %%
type(mysql_page)
# Out:
# pandas.core.frame.DataFrame

# %%
mysql_all.columns
# Out:
# Index(['build_displayname', 'buildTime', 'buildid', 'glmark2', 'glxgears',
#        'UnixBench', 'BoardType', 'OS', 'Test_Host_IP', 'heaven_1080P_low',
#        'valley_1080P_low', 'gfx_bench_manhattan31_off', 'heaven_1080P_high',
#        'valley_1080P_high', 'heaven_1080P_ultra', 'valley_1080P_ultra',
#        'webgl', 'gles_manhattan31', 'gles_manhattan_off', 'gles_manhattan',
#        'gl_manhattan_off', 'gl_manhattan'],
#       dtype='object')

# %%
mysql_all.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1571 entries, 0 to 1570
# Data columns (total 22 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   build_displayname          1571 non-null   datetime64[ns]
#  1   buildTime                  1571 non-null   datetime64[ns]
#  2   buildid                    1571 non-null   object
#  3   glmark2                    1571 non-null   object
#  4   glxgears                   1571 non-null   object
#  5   UnixBench                  1571 non-null   object
#  6   BoardType                  1571 non-null   object
#  7   OS                         1571 non-null   object
#  8   Test_Host_IP               1571 non-null   object
#  9   heaven_1080P_low           1522 non-null   object
#  10  valley_1080P_low           1522 non-null   object
#  11  gfx_bench_manhattan31_off  1206 non-null   object
#  12  heaven_1080P_high          854 non-null    object
# ...
